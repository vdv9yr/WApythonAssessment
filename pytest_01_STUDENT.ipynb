# %% [markdown]
# # Python Screening Test I
#
# **UVA School of Data Science**
#
# Tests for knowledge of Basic Python and Pandas.
#
# ## Instructions
#
# For each task, perform the actions **exactly** as specified.
#
# - For example, if you are asked to write a function that returns a value to a variable, please do so. Printing is not a substitute for returning a value, although you may print the value as well to help you undderstand what is happening in your code.
# - Name files, variables, and functions **exactly** as specified &mdash; character for character and case-sensitive.
#
# You will find any required data files in the Canvas assignment. Download these into the same directory as your work file.
#
# Once you have performed all the tasks listed below, upload your work file to the assignment in Canvas.
#
# - Note that you do not need to upload the data files.
#
# To complete the tasks, all you need is a plain text editor and a copy of Python 3 running on your system. You are of course free to use any editor or development environment you wish to create your file.
#
# Use of generative AI agents to help write code in any way is prohibited. If your programming development environment has AI built into it, either turn it off or use another editor.
#
# - Note that this is for your benefit. Passing this test with the aid of an AI tool undermines the purpose of the assessment, which is to provide you and us with an accurate understanding of your current skills.

# %% [markdown]
# ## Task 0: Open Your Work File
#
# Rename this template file to `pytest_01.ipynb`.
#
# Complete all tasks within the already defined code cells specified for each task. Do not add or remove cells, as this may impact the autograder performance.
#
# *You may also choose to complete this assignment in a `.py` file. See the Canvas instructions for details on completing the assignment that way.*

# %% [markdown]
# ## Task 1: Get Python Version
#
# Import the library `sys`.
#
# Then write and call a function called `get_python_version` that returns the version
# of Python you are running to the variable `python_version`.
#
# Note that the function must return the value and not print it.
# Also note that this function will be run on the testing server, not
# your computer.

# %%
# TASK 1

# %% [markdown]
# ## Task 2: Get Python Path
#
# Write and call a function called `get_python_path` that returns the path of
# the version of Python you are running as the variable `python_path`.
#
# Again, do not print the value, just return it.
#
# Also note that this function will be run on the testing server, not
# your computer, so don't worry about saving the version of Python on your system.

# %%
# TASK 2

# %% [markdown]
# ## Task 3: Combine Strings
#
# Write and call a function called `combine_values` that
# returns a string that combines the previous two values as a string
# in the following format ...
#
# ```
# I am running Python <python_version> on <python_path>.
# ```
#
# ... where  `<python_version>` and `<python_path>` are the values of the variables returned by your previous
# two functions.
#
# Call the function and assign the result to the variable `combined_values`. Note the difference in the name of the variable.

# %%
# TASK 3

# %% [markdown]
# ## Task 4: Read in a File
#
# Write and call a function called `import_file` to read the contents of the file
# `pytest-01-data.txt` as a list of lines.
#
# Save the list as a global variable called `test_lines`.
#
# Be sure the data file is in the same directory as your work file. Your code should refer to the filename only, without any path information.
#
# Then pass the filename as an argument to the function.
#
# Call the function argument `input_file`.

# %%
# TASK 4

# %% [markdown]
# ## Task 5: Count Words
#
# Write and call a function called `count_words` that counts the number of words in the variable `test_lines` that you created above. In the function, pass this variable as an arugment called `list_of_lines`.
#
# When calling the function, return the number of words as an integer to the variable `word_count`.

# %%
# TASK 5

# %% [markdown]
# ## Task 6: Get Distinct Words
#
# Write and call a function called `get_distinct_words` that takes a list of text lines as an argument called `list_of_lines` and returns a list of the distinct words in the list of text lines.
#
# When calling the function, return the value into the variable `distinct_words`.
#
# Make sure the returned word list has no punctuation marks and the words are all lower-cased.

# %%
# TASK 6

# %% [markdown]
# ## Task 7: Cast Data Types
#
# Write a function named `data_type_operations` that takes a single input `x`.
#
# The function should perform the following steps:
#
# - Convert `x` to a string and assign it to a variable named `str_x`.
# - Convert `x` to an integer and assign it to a variable named `int_x`.
# - Convert `x` to a float and assign it to a variable named `float_x`.
# - Convert `x` to a complex number by adding `1j` to it and assign it to a variable named `complex_x`.
# - Convert `x` to a boolean and assign it to a variable named `bool_x`.
#
# Return a dictionary containing the values of `str_x`, `int_x`, `float_x`, `complex_x`, and `bool_x` with their variable names as keys.
#
# Call the function with the argument `42` and return its value to the variable `my_data_types`.

# %%
# TASK 7

# %% [markdown]
# ## Task 8: Create a Dictionary of Lists
#
# Create a dictionary of lists called `my_dictionary_of_lists` with the following features:
#
# - Has a key for each captial letter of the roman alphabet, i.e. A through Z.
# - For each key, assign a list with the following elements (in order):
#     - the integer value corresponding to the ordinal position of the letter in the alphabet, where A is $1$ and Z is $26$.
#     - the integer value returned by calling `ord()`.
#     - the floating point value of the letter's frequency as found in the file `letter-freqs.txt`. Remember to convert the value from a string to a float.
#
# To get the letters of the alphabet as a list, consider importing the `string` library and accessing `string.ascii_uppercase`.\
# To get the letter frequencies, import the file `letter-freqs.txt` and convert it to a dictionary.

# %%
# TASK 8

# %% [markdown]
# ## Task 9: Convert to DataFrame
#
# Take the dictionary created in the previosu task and convert into a Pandas data frame.
#
# Call the new data frame `df`.
#
# The resulting data frame should have three columns for the data in the lists and one named index for the keys (i.e. the letters).
#
# The column names should be: `num`, `ord`, and `freq`.
#
# The index name should be `char_id`.

# %%
# TASK 9

# %% [markdown]
# ## Task 10: Extend the DataFrame
#
# Using the data frame you just created, generate a data frame with the $5$ most frequent letters and one with the $5$ least frequent letters.
#
# Combine these two and save them to the variable `df2`.
#
# The new data frame should be sorted by frequency in descending order and have the same index and column structure as the original data frame, i.e. the index should contain letters and the columns should be the same three as `df`.
#
# In addition to the three columns, the new data frame should have a new column called `type` that contains an `H` for high frequency letters and `L` for low frequency letters.

# %%
# TASK 10
